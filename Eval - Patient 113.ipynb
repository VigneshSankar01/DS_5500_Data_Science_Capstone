# %% [markdown]
# ## Patient Cluster Assignment and Analysis
#
# **Patient Profile (Selected Features)**
#
# | Feature                                         | Value                              |
# | ----------------------------------------------- | ---------------------------------- |
# | General hearing condition                       | Good                               |
# | Had high blood pressure                         | Yes                                |
# | WBC                                             | 4.6                                |
# | Haemoglobin                                     | 11.4                               |
# | Platelets                                       | 239                                |
# | Gender                                          | Female                             |
# | Age                                             | 72                                 |
# | Race/Ethnicity                                  | Non-Hispanic White                 |
# | Country of Birth                                | Born in 50 US states or Washington |
# | Education Level                                 | College graduate or above          |
# | Marital Status                                  | Married/Living with partner        |
# | Household Size                                  | 2                                  |
# | Income-to-Poverty Ratio                         | 4.02                               |
# | Has diabetes                                    | No                                 |
# | Takes vitamin supplements                       | No                                 |
# | Has disability                                  | No                                 |
# | HDL (mg)                                        | 75                                 |
# | Has Hepatitis                                   | No                                 |
# | Covered by health insurance                     | Yes                                |
# | Tested for HIV                                  | No                                 |
# | General health condition                        | Very good                          |
# | Received Hepatitis A Vaccine                    | No                                 |
# | Has Kidney Failure                              | Yes                                |
# | Had Arthritis                                   | Yes                                |
# | Had Cancer                                      | Yes                                |
# | Teeth and gum health                            | Very good                          |
# | Number of Moderate Physical Activities per week | 4                                  |
# | Number of Vigorous Physical Activities per week | 2                                  |
# | Number of Hours of Sleep                        | 9.5                                |
# | Cholesterol Level                               | 198                                |
# | Systolic BP                                     | 121                                |
# | Diastolic BP                                    | 74                                 |
# | Pulse                                           | 62.67                              |
# | BODY_MEASURE_COMPOSITE                          | 0.48                               |
# | Blood_macros                                    | -0.12                              |
# | Mean_steroid_ng_dl                              | -0.45                              |
# | Functional difficulty composite                 | Some difficulty                    |
# | Age Group                                       | 61-75                              |
#
# ---
#
# ### Cluster Assignment
#
# * **Assigned Cluster:** 2 – *Musculoskeletal and respiratory morbidity with metabolic risk*
# * **Nearest Other Cluster:** 1 – *Early cardio-metabolic risk with preserved function*
# * **Distance to Assigned Cluster:** 0.555
# * **Distance to Nearest Cluster:** 1.451
# * **Separation Ratio:** 1.62 (indicating patient is clearly closer to Cluster 2 than Cluster 1)
# * **Cluster Membership Stability:** 1.0 (highly stable assignment)
#
# ---
#
# ### Features Driving Cluster Assignment
#
# **Top features in UMAP space pulling this patient toward Cluster 2:**
#
# | UMAP Feature | Contribution |
# | ------------ | ------------ |
# | UMAP_18      | 0.293        |
# | UMAP_12      | 0.162        |
# | UMAP_17      | 0.159        |
#
# **Top original health features driving assignment:**
#
# | Feature            | Correlation | Contribution |
# | ------------------ | ----------- | ------------ |
# | Has_Kidney_Failure | 0.747       | 0.293        |
# | Has_Kidney_Failure | 0.773       | 0.162        |
# | Has_Kidney_Failure | 0.941       | 0.159        |
#
# **Interpretation:**
# The presence of **kidney failure** is the strongest factor pulling this patient toward Cluster 2. This aligns with Cluster 2’s profile of patients with **musculoskeletal and metabolic risks**, along with moderate chronic disease burden.
#
# ---
#
# ### Clinical Interpretation
#
# * **Why Cluster 2:**
#   This patient has kidney disease and other mild comorbidities (arthritis, cancer history), consistent with Cluster 2’s pattern of musculoskeletal/respiratory morbidity and metabolic risk. Functional difficulties are mild but present, which aligns with Cluster 2’s moderate symptom burden.
#
# * **Comparison with Nearest Cluster (1):**
#   Cluster 1 emphasizes early cardio-metabolic risk with preserved function, mostly hypertension and diabetes without significant musculoskeletal or kidney disease. This patient’s kidney failure and musculoskeletal issues make Cluster 2 a better fit.
#
# * **Implications for Care:**
#
#   * Preventive measures and treatment strategies typical of Cluster 2 should be prioritized (management of kidney health, musculoskeletal support, and monitoring of cholesterol and blood pressure).
#   * Since Cluster 1 focuses on early cardio-metabolic interventions, elements of those strategies may still be considered for prevention of cardiovascular events, given the patient’s age and blood pressure levels.
#
# **Summary Statement:**
#
# > This 72-year-old female patient is most consistent with **Cluster 2**, reflecting multi-system morbidity including kidney disease and musculoskeletal risk. Although not assigned to Cluster 1, some preventive cardio-metabolic strategies from Cluster 1 could be considered alongside Cluster 2’s primary management recommendations.

# %% [markdown]
# This 72-year-old female patient was assigned to **Cluster 2**, characterized by musculoskeletal and respiratory morbidity with metabolic risk. The assignment was primarily driven by the presence of **kidney failure**, which strongly aligns with the cluster’s profile of moderate chronic disease burden, including arthritis and metabolic complications. Functional difficulties were mild but present, consistent with the cluster’s moderate symptomatology. While the patient is nearest to **Cluster 1**, which represents early cardio-metabolic risk with preserved function, the kidney and musculoskeletal comorbidities justify the assignment to Cluster 2. Clinically, this suggests that **management and preventive strategies typical of Cluster 2**—focusing on kidney health, musculoskeletal support, and metabolic monitoring—are most relevant. However, elements of **cardio-metabolic preventive care from Cluster 1** may also be considered to mitigate future cardiovascular risk, allowing a more tailored and proactive care approach.
