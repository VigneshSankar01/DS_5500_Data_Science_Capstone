# %% [markdown]
# ## Patient Cluster Assignment and Analysis
#
# **Patient Cluster Assignment:** Cluster 4
# **Nearest Other Cluster:** Cluster 2
# **Distance to Assigned Cluster:** 0.457
# **Distance to Nearest Cluster:** 3.487
# **Separation Ratio:** 6.632
# **Cluster Membership Stability:** 1.00
#
# ### Summary
#
# This patient is assigned to **Cluster 4** because their overall health profile is much closer to the centroid of Cluster 4 in UMAP feature space compared to Cluster 2. The separation ratio of **6.63** indicates a strong and stable cluster assignment. This suggests that Cluster 4 characteristics best describe the patient’s health and risk profile.
#
# ### Key Features Driving Cluster Assignment
#
# | Feature            | Contribution | Correlation |
# | ------------------ | ------------ | ----------- |
# | Has_Kidney_Failure | 0.328        | 0.941       |
# | Has_Kidney_Failure | 0.243        | 0.965       |
# | mean_steroid_ng_dl | 0.159        | 0.465       |
#
# The assignment is largely driven by **kidney function and steroid levels**, which are critical in distinguishing Cluster 4 from other clusters.
#
# ### Patient Health Profile
#
# | Feature                           | Value                       |
# | --------------------------------- | --------------------------- |
# | General Hearing Condition         | Good                        |
# | Had High Blood Pressure           | No                          |
# | WBC                               | 6.5                         |
# | Haemoglobin                       | 14.4                        |
# | Platelet                          | 212                         |
# | Gender                            | Male                        |
# | Age                               | 58                          |
# | Race/Ethnicity                    | Non-Hispanic White          |
# | Education Level                   | College graduate or above   |
# | Marital Status                    | Married/Living with partner |
# | Household Size                    | 7                           |
# | Income to Poverty Ratio           | 3.02                        |
# | Has Diabetes                      | No                          |
# | Takes Vitamin Supplements         | No                          |
# | Has Disability                    | No                          |
# | HDL (mg)                          | 53                          |
# | Has Hepatitis                     | No                          |
# | Covered by Health Insurance       | Yes                         |
# | Tested for HIV Virus              | No                          |
# | General Health Condition          | Very good                   |
# | Teeth and Gum Health              | Good                        |
# | Moderate Physical Activities/Week | 7                           |
# | Vigorous Physical Activities/Week | 195                         |
# | Hours of Sleep                    | 105.7                       |
# | Functional Difficulty             | No difficulty               |
# | Age Group                         | 46–60                       |
#
# ### Comparison with Nearest Cluster (Cluster 2)
#
# * The patient is **much further from Cluster 2** (distance = 3.487), which is characterized by lower kidney-related contributions and slightly different metabolic markers.
# * While Cluster 2 contains features relevant to metabolic risk and steroid-related measurements, the patient’s **kidney-related markers are more aligned with Cluster 4**, supporting their primary assignment.
#
# ### Interpretation and Clinical Implications
#
# 1. **Primary Recommendation:** Treatments, preventive strategies, and diagnostic approaches suggested for **Cluster 4** are most relevant to this patient.
# 2. **Secondary Consideration:** Due to partial overlap in steroid-related markers with Cluster 2, clinicians may consider monitoring **steroid metabolism or other early metabolic indicators** that are characteristic of Cluster 2 for proactive health management.
# 3. **Overall Conclusion:** The patient’s profile strongly aligns with Cluster 4, but knowledge of Cluster 2 characteristics could inform **early detection and preventive care**, particularly for metabolic and cardiovascular health.
