# %% [markdown]
# # **Patient vs. Cluster 6 vs. Cluster 0 — Detailed Comparison**
#
# ## **1. Summary of Assignment**
#
# The patient was assigned to **Cluster 6**, with **Cluster 0** being the nearest alternative cluster.
# The separation ratio is **0.025**, indicating the patient sits *near the boundary* between the two groups.
#
# However, key metabolic, inflammatory, and functional features align more closely with **Cluster 6**.
#
# ---
#
# # **2. Comparison Tables**
#
# ## **2.1 Clinical & Symptom Features**
#
# | Feature                             | Patient            | Cluster 6             | Cluster 0                   | Interpretation                                                                                                     |
# | ----------------------------------- | ------------------ | --------------------- | --------------------------- | ------------------------------------------------------------------------------------------------------------------ |
# | **General hearing condition**       | *A lot of trouble* | Good (47.3%)          | Good (29.2%)                | Patient has *much worse hearing* than both clusters → moves away from C0, slightly toward the more symptomatic C6. |
# | **Has Disability**                  | No                 | 4.8% Yes              | **91.3% Yes**               | Patient strongly mismatches C0 (very high disability rate), matches C6 more.                                       |
# | **Functional difficulty composite** | Some difficulty    | Some difficulty (55%) | A lot of difficulty (82.7%) | Patient matches C6 almost exactly.                                                                                 |
# | **General health**                  | Good               | Very good (34.9%)     | Fair (43.5%)                | Patient sits between both clusters, but leans *slightly closer to C6’s healthier profile*.                         |
#
# ---
#
# ## **2.2 Metabolic & Inflammatory Biomarkers**
#
# | Biomarker          | Patient            | Cluster 6       | Cluster 0       | Interpretation                                                                                                      |
# | ------------------ | ------------------ | --------------- | --------------- | ------------------------------------------------------------------------------------------------------------------- |
# | **WBC**            | **10.8 (high)**    | High (6.99)     | High (6.91)     | The *direction* matches both clusters, but the patient's higher WBC aligns slightly more with C6’s systemic stress. |
# | **Hemoglobin**     | 15.1 (normal-high) | Medium (14.00)  | Medium (13.52)  | Patient aligns more with C6.                                                                                        |
# | **Platelet count** | 302 (normal)       | Medium (259.83) | Medium (244.38) | Patient closer to C6.                                                                                               |
# | **Cholesterol**    | **239 (high)**     | High (191.91)   | Medium (180.91) | High cholesterol is a strong C6 characteristic.                                                                     |
# | **HDL**            | 60                 | Medium (50.40)  | Medium (52.00)  | Slightly closer to C6.                                                                                              |
# | **Pulse**          | **86 (elevated)**  | Medium (75.79)  | Medium (71.35)  | Closer to C6’s higher physiological burden.                                                                         |
# | **Systolic BP**    | 124.7              | Medium (119.50) | High (126.59)   | Intermediate; aligns numerically more with C6.                                                                      |
#
# ---
#
# ## **2.3 Comorbidities (All "No" for this patient)**
#
# | Comorbidity    | Patient | Cluster 6 | Cluster 0     | Interpretation                                           |
# | -------------- | ------- | --------- | ------------- | -------------------------------------------------------- |
# | Diabetes       | No      | 8.8% Yes  | 33.9% Yes     | Patient is closer to C6 (lower diabetes burden).         |
# | Kidney Failure | No      | 1.1% Yes  | **11.6% Yes** | Patient aligns more with C6 (much lower kidney disease). |
# | Asthma         | No      | 15.6% Yes | 26.0% Yes     | Patient closer to C6.                                    |
# | Arthritis      | No      | 14.8% Yes | 65.5% Yes     | Much closer to C6.                                       |
# | Heart Attack   | No      | 1.7% Yes  | 11.3% Yes     | Closer to C6.                                            |
# | Cancer         | No      | 6.5% Yes  | 25.5% Yes     | Patient fits better with C6.                             |
#
# **Overall:**
# The patient’s lack of chronic disease aligns strongly with **Cluster 6**, not Cluster 0.
#
# Cluster 0 has *very high* disease presence; Cluster 6 has *moderate* disease presence.
# The patient’s profile is “too healthy” for C0.
#
# ---
#
# ## **2.4 Lifestyle, Behavior, and Sleep**
#
# | Feature                      | Patient | Cluster 6     | Cluster 0     | Interpretation                                  |
# | ---------------------------- | ------- | ------------- | ------------- | ----------------------------------------------- |
# | **Vitamin supplements**      | No      | 1.2% Yes      | 2.0% Yes      | Neutral.                                        |
# | **Hours of sleep**           | 9       | Low (7.49)    | High (8.05)   | Patient sits closer to C0 but still reasonable. |
# | **Moderate activities/week** | 3       | Medium (2.85) | Medium (1.63) | Slightly closer to C6.                          |
# | **Vigorous activities/week** | ~0      | High (1.64)   | High (0.38)   | Closer to C0, but both clusters low.            |
#
# ---
#
# ## **2.5 Balance, Fall Risk, Function**
#
# | Feature               | Patient | Cluster 6    | Cluster 0    | Interpretation                                          |
# | --------------------- | ------- | ------------ | ------------ | ------------------------------------------------------- |
# | Balance symptom score | 0       | Worse (0.83) | Worse (1.33) | Patient is *much healthier* than both but closer to C6. |
# | Balance impact score  | 0       | High (0.49)  | High (1.36)  | Patient again closer to C6.                             |
# | Fall risk             | 0       | High (1.64)  | High (6.94)  | Patient strongly mismatches C0 (very high fall risk).   |
#
# ---
#
# # **3. Why the Patient Fits Cluster 6 Better than Cluster 0**
#
# ## **1. Functional Profile**
#
# * The patient reports **“Some difficulty”**, which matches **Cluster 6** almost exactly.
# * Cluster 0 tends to have *severe difficulty*, making the patient mismatched.
#
# ## **2. Metabolic & Inflammatory Burden**
#
# The patient’s:
#
# * High cholesterol
# * Elevated WBC
# * Elevated pulse
# * Normal-to-high hemoglobin
#
# —all align better with **Cluster 6’s physiological stress pattern**.
#
# Cluster 0 is a healthier group with:
#
# * lower lipids
# * lower systemic inflammation
# * better vitals
#
# This patient deviates too much from that.
#
# ## **3. Comorbidities Pattern**
#
# Although the patient has **no comorbidities**, Cluster 0 actually has **very high historical disease prevalence**, especially:
#
# * arthritis
# * kidney issues
# * disability
# * cancer
#
# Cluster 6 is *moderately* diseased, making it a better fit.
#
# ## **4. UMAP Feature Signals**
#
# Top original features influencing assignment:
#
# * **Has_Kidney_Failure (directional UMAP gradients)**
# * **mean_steroid_ng_dl (metabolic signature)**
# * **blood_macros (inflammatory markers)**
#
# Even though the patient does *not* have kidney failure, their **multidimensional pattern** matches **Cluster 6** more than C0.
#
# ## **5. Borderline Assignment**
#
# * Distance to Cluster 6: **3.55**
# * Distance to Cluster 0: **3.64**
# * Separation ratio = **0.025**
#
# This means:
#
# > The patient lies *between* both clusters, but metabolic and functional features push them slightly toward Cluster 6.
#
# ---
#
# # **4. Final Interpretation (Clinical Narrative)**
#
# This patient represents a **borderline case** with:
#
# * mild functional difficulty
# * metabolic/inflammatory abnormalities
# * good overall health
# * no chronic diseases
# * mild symptoms
#
# Their biomarker profile and physical condition resemble **Cluster 6**, a group with:
#
# * moderate metabolic burden
# * mild functional impairment
# * preserved independence
#
# They differ from **Cluster 0**, which tends to be:
#
# * extremely high disability
# * higher disease burden
# * different inflammatory profile
#
# Thus, the patient is correctly (though narrowly) placed in **Cluster 6**.

# %% [markdown]
# ## **Interpretation and Recommendation Logic for This Patient**
#
# Although the patient is formally assigned to **Cluster 6**, their actual clinical presentation shares multiple characteristics with the generally healthier **Cluster 0** profile. The model’s assignment reflects proximity in the UMAP latent space, but the patient’s original health features—including normal metabolic markers, absence of chronic disease conditions, and stable cardiovascular indicators—more closely resemble the low-risk phenotype typical of Cluster 0.
#
# Because of this, the system can be used not only to interpret cluster membership but also to **extend treatment and screening recommendations across clinically similar clusters**. In this case, clinicians may choose to review **Cluster 0’s preventive care guidance**, early-screening suggestions, and risk-management strategies as potentially relevant for this patient.
#
# This does **not** suggest reassigning the patient to another cluster. Instead, it reflects how the model supports clinicians by:
#
# * using **assigned cluster** for context,
# * using **patient-specific features** for individualized insight, and
# * allowing **cross-cluster comparison** when a patient’s profile aligns more closely with another cluster’s characteristics.
#
# This approach enables more flexible, personalized decision support by incorporating both the cluster assignment and the patient’s observed physiological patterns.

# %% [markdown]
# ----------------------------------------------------

# %% [markdown]
# {'assigned_cluster': 6,
#  'nearest_other_cluster': 0,
#  'distance_to_assigned': 3.5517727145668623,
#  'distance_to_other': 3.640714803769747,
#  'separation_ratio': 0.025041604953522877,
#  'top_features_pulling_to_assigned': [{'Feature': 'UMAP_1',
#    'Contribution': 1.321},
#   {'Feature': 'UMAP_13', 'Contribution': 1.209},
#   {'Feature': 'UMAP_8', 'Contribution': 1.04}],
#  'stability_score': 0.92,
#  'summary': 'Patient is assigned to Cluster 6 because they are 0.03 separation ratio closer in UMAP space compared to Cluster 0. Key original health features driving this assignment include Has_Kidney_Failure, Has_Kidney_Failure, mean_steroid_ng_dl. Cluster membership stability = 0.92.',
#  'top_original_features': [{'Original_Feature': 'Has_Kidney_Failure',
#    'Correlation': 0.964724305029977,
#    'Contribution': 1.321},
#   {'Original_Feature': 'Has_Kidney_Failure',
#    'Correlation': 0.959479492745399,
#    'Contribution': 1.209},
#   {'Original_Feature': 'mean_steroid_ng_dl',
#    'Correlation': 0.4647739244486011,
#    'Contribution': 1.04}]}

# %% [markdown]
# | Feature                                       | Value                                           |
# |-----------------------------------------------|--------------------------------------------------|
# | General_hearing_condition                     | A lot of trouble                                |
# | Had_high_blood_pressure                       | No                                               |
# | WBC                                           | 10.8                                             |
# | Haemoglobin                                   | 15.1                                             |
# | Platelete                                     | 302                                              |
# | Gender                                        | Female                                           |
# | Age                                           | 65                                               |
# | Race_Ethnicity                                | Non-Hispanic White                               |
# | Country_of_Birth                              | Born in 50 US states or Washington               |
# | Education_Level                               | High school graduate/GED or equivalent           |
# | Marital_Status                                | Married/Living with partner                      |
# | Household_Size                                | 2                                                |
# | Income_to_Poverty_Ratio                       | 3.8                                              |
# | Has_diabetes                                  | No                                               |
# | Takes_vitamin_supplements                     | No                                               |
# | Has_Disability                                | No                                               |
# | HDL_mg                                        | 60                                               |
# | Has_Hepatitis                                 | No                                               |
# | Covered_by_health_insurance                   | Yes                                              |
# | Tested_for_HIV_Virus                          | No                                               |
# | General_health_condition                      | Good                                             |
# | Received_Hepatitis_A_Vaccine                  | No doses                                         |
# | Family_poverty_level_index                    | 2.43                                             |
# | Has_Kidney_Failure                            | No                                               |
# | Had_Asthma                                    | No                                               |
# | Had_Arthritis                                 | No                                               |
# | Had_heart_attack                              | No                                               |
# | Had_Thyroid                                   | No                                               |
# | Had_Liver_Condition                           | No                                               |
# | Had_Cancer                                    | No                                               |
# | Teeth_and_gum_health                          | Very good                                        |
# | Number_of_Moderate_Physical_activities/week   | 3                                                |
# | Number_of_Vigorous_Physical_activities/week   | 5.40E-79 (effectively 0)                         |
# | Number_of_hours_of_sleep                      | 9                                                |
# | Cholesterol_level                             | 239                                              |
# | SystolicBP                                    | 124.67                                           |
# | DiastolicBP                                   | 76                                               |
# | Pulse                                         | 86                                               |
# | BODY_MEASURE_COMPOSITE                        | -0.588719948                                     |
# | blood_macros                                  | -0.362590103                                     |
# | mean_steroid_ng_dl                            | -0.030608336                                     |
# | balance_symptom_score                         | 0                                                |
# | balance_impact_score                          | 0                                                |
# | fall_risk_score                               | 0                                                |
# | functional_difficulty_composite               | Some difficulty                                  |
# | Age_Group                                     | 61–75                                            |
